# %% [markdown]
# # Basics of  K-Means Clustering

# %% [markdown]
# ### Import Libraries

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
sns.set()
from sklearn.cluster import KMeans

# %% [markdown]
# ### Load the data

# %%
data = pd.read_csv("https://docs.google.com/spreadsheets/d/1_3a04vjJjRBbX_uJJgE1BXjEq3GyEiKuHm1kzFSfdyI/export?gid=1503473325&format=csv")
data
# Out:
#      Country  Latitude  Longitude Language
# 0        USA     44.97    -103.77  English
# 1     Canada     62.40     -96.80  English
# 2     France     46.75       2.40   French
# 3         UK     54.01      -2.53  English
# 4    Germany     51.15      10.40   German
# 5  Australia    -25.45     133.11  English

# %% [markdown]
# ### Plot the Data

# %%
plt.scatter(data['Longitude'], data['Latitude'])
plt.xlim(-180, 180)
plt.ylim(-90, 90)
plt.show();

# %% [markdown]
# ### Select Feature

# %%
x = data.iloc[: , 1:3]

# %%
x
# Out:
#    Latitude  Longitude
# 0     44.97    -103.77
# 1     62.40     -96.80
# 2     46.75       2.40
# 3     54.01      -2.53
# 4     51.15      10.40
# 5    -25.45     133.11

# %% [markdown]
# ### Clustering

# %%
Kmeans = KMeans(3)

# %%
Kmeans.fit(x)
# Out:
# KMeans(n_clusters=3)

# %%
id_cluster = Kmeans.fit_predict(x)
id_cluster
# Out:
# array([2, 2, 0, 0, 0, 1], dtype=int32)

# %%
data_with_cluster = data.copy()
data_with_cluster["cluster"] = id_cluster
data_with_cluster
# Out:
#      Country  Latitude  Longitude Language  cluster
# 0        USA     44.97    -103.77  English        2
# 1     Canada     62.40     -96.80  English        2
# 2     France     46.75       2.40   French        0
# 3         UK     54.01      -2.53  English        0
# 4    Germany     51.15      10.40   German        0
# 5  Australia    -25.45     133.11  English        1

# %%
plt.scatter(data_with_cluster['Longitude'], data_with_cluster['Latitude'], c = data_with_cluster['cluster'], cmap='rainbow')
plt.xlim(-180, 180)
plt.ylim(-90, 90)
plt.show();

# %% [markdown]
# Now we will try with more countries

# %%
data_new = pd.read_csv("https://docs.google.com/spreadsheets/d/1n9hdRZgcpdXNxviNJOZIFzZwUbjqa6hR4PeeYSJROus/export?gid=258509875&format=csv")
data_new
# Out:
#              name   Longitude   Latitude
# 0           Aruba  -69.982677  12.520880
# 1     Afghanistan   66.004734  33.835231
# 2          Angola   17.537368 -12.293361
# 3        Anguilla  -63.064989  18.223959
# 4         Albania   20.049834  41.142450
# ..            ...         ...        ...
# 236         Samoa -172.164851 -13.753243
# 237         Yemen   47.586762  15.909280
# 238  South Africa   25.083901 -29.000341
# 239        Zambia   27.774759 -13.458242
# 240      Zimbabwe   29.851441 -19.004204
#
# [241 rows x 3 columns]

# %%
x = data_new.iloc[: , 1:3]
x.head()
# Out:
#    Longitude   Latitude
# 0 -69.982677  12.520880
# 1  66.004734  33.835231
# 2  17.537368 -12.293361
# 3 -63.064989  18.223959
# 4  20.049834  41.142450

# %%
kmeans = KMeans(7)
kmeans.fit(x)
# Out:
# KMeans(n_clusters=7)

# %%
new_id_cluster = kmeans.fit_predict(x)
new_id_cluster
# Out:
# array([5, 4, 6, 5, 4, 4, 4, 6, 5, 4, 2, 6, 1, 6, 5, 1, 4, 4, 6, 4, 0, 0,
#        1, 4, 6, 3, 5, 4, 5, 4, 5, 3, 5, 5, 5, 1, 1, 6, 0, 4, 5, 1, 0, 0,
#        6, 0, 2, 5, 6, 0, 5, 5, 5, 5, 4, 4, 4, 4, 6, 5, 4, 5, 0, 5, 4, 6,
#        4, 4, 6, 4, 1, 5, 4, 4, 1, 0, 4, 4, 4, 0, 0, 0, 0, 0, 4, 5, 3, 5,
#        1, 5, 1, 6, 5, 4, 5, 4, 1, 4, 1, 1, 6, 4, 4, 4, 4, 4, 4, 5, 4, 4,
#        1, 1, 4, 6, 4, 1, 5, 5, 1, 4, 4, 1, 4, 0, 4, 5, 4, 6, 6, 4, 4, 4,
#        1, 5, 0, 4, 4, 6, 6, 3, 1, 4, 0, 4, 1, 4, 1, 1, 6, 0, 5, 6, 6, 1,
#        6, 1, 0, 1, 0, 5, 2, 4, 4, 1, 1, 1, 6, 6, 5, 2, 5, 1, 1, 1, 4, 5,
#        1, 0, 5, 4, 2, 6, 4, 1, 6, 0, 6, 6, 6, 0, 1, 5, 0, 1, 0, 5, 4, 6,
#        6, 3, 4, 0, 5, 4, 4, 4, 6, 5, 6, 4, 5, 0, 0, 1, 4, 4, 1, 2, 5, 4,
#        4, 1, 6, 6, 4, 5, 3, 4, 4, 5, 5, 5, 5, 1, 1, 2, 2, 6, 6, 6, 6],
#       dtype=int32)

# %%
data_more_cluster = data_new.copy()
data_more_cluster['cluster'] = new_id_cluster
data_more_cluster.head()
# Out:
#           name  Longitude   Latitude  cluster
# 0        Aruba -69.982677  12.520880        5
# 1  Afghanistan  66.004734  33.835231        4
# 2       Angola  17.537368 -12.293361        6
# 3     Anguilla -63.064989  18.223959        5
# 4      Albania  20.049834  41.142450        4

# %%
plt.scatter(data_more_cluster['Longitude'], data_more_cluster['Latitude'], c = data_more_cluster['cluster'], cmap='rainbow')
plt.xlim(-180, 180)
plt.ylim(-90, 90)
plt.show();

# %% [markdown]
# ### Dealing with Category Variables

# %%
data_cat = pd.read_csv("https://docs.google.com/spreadsheets/d/1-rolBHTMBzH1ZQqqtMDb17cxJq_ddlGWhI_jDrX6xyI/export?gid=172986750&format=csv")
data_cat
# Out:
#              name   Longitude   Latitude      continent
# 0           Aruba  -69.982677  12.520880  North America
# 1     Afghanistan   66.004734  33.835231           Asia
# 2          Angola   17.537368 -12.293361         Africa
# 3        Anguilla  -63.064989  18.223959  North America
# 4         Albania   20.049834  41.142450         Europe
# ..            ...         ...        ...            ...
# 236         Samoa -172.164851 -13.753243        Oceania
# 237         Yemen   47.586762  15.909280           Asia
# 238  South Africa   25.083901 -29.000341         Africa
# 239        Zambia   27.774759 -13.458242         Africa
# 240      Zimbabwe   29.851441 -19.004204         Africa
#
# [241 rows x 4 columns]

# %%
data_cat['cat_continent'] = data_cat['continent'].map({'North America':0,'Europe':1,'Asia':2,'Africa':3,'South America':4, 'Oceania':5,'Seven seas (open ocean)':6, 'Antarctica':7})
data_cat
# Out:
#              name   Longitude   Latitude      continent  cat_continent
# 0           Aruba  -69.982677  12.520880  North America              0
# 1     Afghanistan   66.004734  33.835231           Asia              2
# 2          Angola   17.537368 -12.293361         Africa              3
# 3        Anguilla  -63.064989  18.223959  North America              0
# 4         Albania   20.049834  41.142450         Europe              1
# ..            ...         ...        ...            ...            ...
# 236         Samoa -172.164851 -13.753243        Oceania              5
# 237         Yemen   47.586762  15.909280           Asia              2
# 238  South Africa   25.083901 -29.000341         Africa              3
# 239        Zambia   27.774759 -13.458242         Africa              3
# 240      Zimbabwe   29.851441 -19.004204         Africa              3
#
# [241 rows x 5 columns]

# %%
x = data_cat.iloc[:,4:5]
x
# Out:
#      cat_continent
# 0                0
# 1                2
# 2                3
# 3                0
# 4                1
# ..             ...
# 236              5
# 237              2
# 238              3
# 239              3
# 240              3
#
# [241 rows x 1 columns]

# %%
kmeans_cat = KMeans(7)
kmeans_cat.fit(x)
# Out:
# KMeans(n_clusters=7)

# %%
new_cluster_cat = data_cat.copy()
new_cluster_cat['cluster'] = kmeans_cat.fit_predict(x)
new_cluster_cat
# Out:
#              name   Longitude   Latitude      continent  cat_continent  \
# 0           Aruba  -69.982677  12.520880  North America              0
# 1     Afghanistan   66.004734  33.835231           Asia              2
# 2          Angola   17.537368 -12.293361         Africa              3
# 3        Anguilla  -63.064989  18.223959  North America              0
# 4         Albania   20.049834  41.142450         Europe              1
# ..            ...         ...        ...            ...            ...
# 236         Samoa -172.164851 -13.753243        Oceania              5
# 237         Yemen   47.586762  15.909280           Asia              2
# 238  South Africa   25.083901 -29.000341         Africa              3
# 239        Zambia   27.774759 -13.458242         Africa              3
# 240      Zimbabwe   29.851441 -19.004204         Africa              3
#
#      cluster
# 0          0
# 1          3
# 2          2
# 3          0
# 4          4
# ..       ...
# 236        1
# 237        3
# 238        2
# 239        2
# 240        2
#
# [241 rows x 6 columns]

# %%
plt.scatter(new_cluster_cat['Longitude'], new_cluster_cat['Latitude'], c = new_cluster_cat['cluster'], cmap='rainbow')
plt.xlim(-180, 180)
plt.ylim(-90, 90)
plt.show();

# %% [markdown]
# To get the WCSS(within cluster sum of squares)

# %%
kmeans_cat.inertia_
# Out:
# 0.8888888888888888

# %%
wcss = []
x = data_cat.iloc[:,1:3]
for i in range(1,31):
    kmeans_cat = KMeans(i)
    kmeans_cat.fit(x)
    wcss_iter = kmeans_cat.inertia_
    wcss.append(wcss_iter)

# %%
wcss
# Out:
# [1413859.6798344275,
#  657012.0797586325,
#  325255.15398078033,
#  256590.585754061,
#  196256.69158420304,
#  197016.703604029,
#  173124.21535636234,
#  109037.89720959184,
#  85096.33351772626,
#  83770.61270024389,
#  74228.76920570905,
#  67893.69222755518,
#  62411.79611611581,
#  59105.367836756406,
#  52812.15638523777,
#  50995.013960879296,
#  46223.50964521151,
#  42672.87326928493,
#  39863.38891762805,
#  37728.1284216808,
#  36126.976921853406,
#  32067.01750024584,
#  33968.21347919067,
#  29857.760321183774,
#  30787.058494484045,
#  26836.305553839673,
#  23980.68462427566,
#  23959.96695831245,
#  24147.56952115678,
#  21490.923985418605]

# %%
number_clusters = range(1,31)
plt.plot(number_clusters, wcss)
plt.title('The Elbow Method')
plt.xlabel('Number of clusters')
plt.ylabel('Within-cluster Sum of Squares')
# Here 10 is the optimum cluster
# Out:
# Text(0, 0.5, 'Within-cluster Sum of Squares')
