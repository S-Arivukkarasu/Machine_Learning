# %%
import openml

# %%
# List all datasets and their properties
openml.datasets.list_datasets(output_format="dataframe")
# Out:
#          did                       name  version uploader  status format  \
# 2          2                     anneal        1        1  active   ARFF
# 3          3                   kr-vs-kp        1        1  active   ARFF
# 4          4                      labor        1        1  active   ARFF
# 5          5                 arrhythmia        1        1  active   ARFF
# 6          6                     letter        1        1  active   ARFF
# ...      ...                        ...      ...      ...     ...    ...
# 46346  46346          tiny-imagenet-200        4    42266  active   arff
# 46347  46347       tiniest-imagenet-200        1    42266  active   arff
# 46348  46348                       mxmh        1    45150  active   arff
# 46349  46349                      Wheat        1    45167  active   arff
# 46351  46351  mango_detection_australia        1    45322  active   arff
#
#        MajorityClassSize  MaxNominalAttDistinctValues  MinorityClassSize  \
# 2                  684.0                          7.0                8.0
# 3                 1669.0                          3.0             1527.0
# 4                   37.0                          3.0               20.0
# 5                  245.0                         13.0                2.0
# 6                  813.0                         26.0              734.0
# ...                  ...                          ...                ...
# 46346              500.0                          NaN              500.0
# 46347               20.0                          NaN               20.0
# 46348                NaN                          NaN                NaN
# 46349                NaN                          NaN                NaN
# 46351                NaN                          NaN                NaN
#
#        NumberOfClasses  NumberOfFeatures  NumberOfInstances  \
# 2                  5.0              39.0              898.0
# 3                  2.0              37.0             3196.0
# 4                  2.0              17.0               57.0
# 5                 13.0             280.0              452.0
# 6                 26.0              17.0            20000.0
# ...                ...               ...                ...
# 46346            200.0               3.0           100000.0
# 46347            200.0               2.0             4000.0
# 46348              NaN              33.0              736.0
# 46349              NaN              13.0            10642.0
# 46351              NaN              12.0            10619.0
#
#        NumberOfInstancesWithMissingValues  NumberOfMissingValues  \
# 2                                   898.0                22175.0
# 3                                     0.0                    0.0
# 4                                    56.0                  326.0
# 5                                   384.0                  408.0
# 6                                     0.0                    0.0
# ...                                   ...                    ...
# 46346                                 0.0                    0.0
# 46347                                 0.0                    0.0
# 46348                               120.0                  129.0
# 46349                             10642.0                10642.0
# 46351                                 0.0                    0.0
#
#        NumberOfNumericFeatures  NumberOfSymbolicFeatures
# 2                          6.0                      33.0
# 3                          0.0                      37.0
# 4                          8.0                       9.0
# 5                        206.0                      74.0
# 6                         16.0                       1.0
# ...                        ...                       ...
# 46346                      1.0                       0.0
# 46347                      0.0                       0.0
# 46348                      7.0                       0.0
# 46349                     13.0                       0.0
# 46351                      8.0                       0.0
#
# [5760 rows x 16 columns]

# %%
dataset = openml.datasets.get_dataset(61)

# %%
dataset
# Out:
# OpenML Dataset
# ==============
# Name.........: iris
# Version......: 1
# Format.......: ARFF
# Upload Date..: 2014-04-06 23:23:39
# Licence......: Public
# Download URL.: https://api.openml.org/data/v1/download/61/iris.arff
# OpenML URL...: https://www.openml.org/d/61
# # of features: None

# %%
X= dataset.get_data(dataset_format="dataframe")

# %%
X[0]
# Out:
#      sepallength  sepalwidth  petallength  petalwidth           class
# 0            5.1         3.5          1.4         0.2     Iris-setosa
# 1            4.9         3.0          1.4         0.2     Iris-setosa
# 2            4.7         3.2          1.3         0.2     Iris-setosa
# 3            4.6         3.1          1.5         0.2     Iris-setosa
# 4            5.0         3.6          1.4         0.2     Iris-setosa
# ..           ...         ...          ...         ...             ...
# 145          6.7         3.0          5.2         2.3  Iris-virginica
# 146          6.3         2.5          5.0         1.9  Iris-virginica
# 147          6.5         3.0          5.2         2.0  Iris-virginica
# 148          6.2         3.4          5.4         2.3  Iris-virginica
# 149          5.9         3.0          5.1         1.8  Iris-virginica
#
# [150 rows x 5 columns]

# %%
from sklearn import ensemble
from openml import tasks, runs

# List all tasks in a benchmark
benchmark = openml.study.get_suite('OpenML-CC18')
tasks.list_tasks(output_format="dataframe", task_id=benchmark.tasks)

# Return benchmark results
openml.evaluations.list_evaluations(
    function="area_under_roc_curve",
    tasks=benchmark.tasks,
    output_format="dataframe"
)
# Out:
#         run_id  task_id  setup_id  flow_id  \
# 0           28        3        18       77
# 1           78        3         3       58
# 2          139        3         2       57
# 3          217        3         7       62
# 4          221        3         6       61
# ...        ...      ...       ...      ...
# 9995  10046421        3   7971068     8815
# 9996  10046459        3   7971107     8815
# 9997  10046499        3   7971148     8815
# 9998  10046616        3   7971269     8815
# 9999  10046743        3   7971399     8815
#
#                                               flow_name  data_id data_name  \
# 0                      weka.LogitBoost_DecisionStump(1)        3  kr-vs-kp
# 1                                    weka.NaiveBayes(1)        3  kr-vs-kp
# 2                                          weka.OneR(1)        3  kr-vs-kp
# 3                                 weka.DecisionStump(1)        3  kr-vs-kp
# 4                                       weka.REPTree(1)        3  kr-vs-kp
# ...                                                 ...      ...       ...
# 9995  sklearn.pipeline.Pipeline(columntransformer=sk...        3  kr-vs-kp
# 9996  sklearn.pipeline.Pipeline(columntransformer=sk...        3  kr-vs-kp
# 9997  sklearn.pipeline.Pipeline(columntransformer=sk...        3  kr-vs-kp
# 9998  sklearn.pipeline.Pipeline(columntransformer=sk...        3  kr-vs-kp
# 9999  sklearn.pipeline.Pipeline(columntransformer=sk...        3  kr-vs-kp
#
#                   function          upload_time  uploader uploader_name  \
# 0     area_under_roc_curve  2014-04-06 23:47:04         1  Jan van Rijn
# 1     area_under_roc_curve  2014-04-07 00:03:46         1  Jan van Rijn
# 2     area_under_roc_curve  2014-04-07 00:46:29         1  Jan van Rijn
# 3     area_under_roc_curve  2014-04-07 01:25:07         1  Jan van Rijn
# 4     area_under_roc_curve  2014-04-07 01:27:12         1  Jan van Rijn
# ...                    ...                  ...       ...           ...
# 9995  area_under_roc_curve  2019-01-24 23:56:55         1  Jan van Rijn
# 9996  area_under_roc_curve  2019-01-24 23:57:03         1  Jan van Rijn
# 9997  area_under_roc_curve  2019-01-24 23:57:16         1  Jan van Rijn
# 9998  area_under_roc_curve  2019-01-24 23:57:48         1  Jan van Rijn
# 9999  area_under_roc_curve  2019-01-24 23:58:16         1  Jan van Rijn
#
#          value values           array_data
# 0     0.977253   None  [0.977253,0.977253]
# 1     0.951281   None  [0.951281,0.951281]
# 2     0.666985   None  [0.666985,0.666985]
# 3     0.666432   None  [0.666432,0.666432]
# 4     0.997912   None  [0.997912,0.997912]
# ...        ...    ...                  ...
# 9995  0.996367   None  [0.996367,0.996367]
# 9996  0.997402   None  [0.997402,0.997402]
# 9997  0.997317   None  [0.997317,0.997317]
# 9998  0.996206   None  [0.996206,0.996206]
# 9999  0.996488   None  [0.996488,0.996488]
#
# [10000 rows x 14 columns]
