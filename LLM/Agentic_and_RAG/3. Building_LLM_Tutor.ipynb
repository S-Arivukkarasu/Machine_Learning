# %% [markdown]
# # Building LLM Tutor Assignment

# %%
# Importing the Libraries

import requests
import json
import time
import re
from typing import List
from bs4 import BeautifulSoup
from IPython.display import Markdown, display, update_display

# %%
MODEL_NAME="mistral"  # Get this from you local ollama by using "ollama list"
OLLAMA_URL = "http://localhost:11434/api/chat"

# %%
question = """
Please explain what this code does and why:
yield from {book.get("author") for book in books if book.get("author")}
"""

# %%
system_prompt = "You are a helpful technical tutor who answers questions about python code, software engineering, data science and LLMs"
user_prompt = "Please give a detailed explanation to the following question: " + question

# %%
messages = [
    {"role": "system", "content": system_prompt},
    {"role": "user", "content": user_prompt}
]

# %%
payload = {
        "model": MODEL_NAME,
        "messages": messages,
        "stream": False  # Important: to get streaming responses
    }

# %%
start_time = time.time()
response = requests.post(OLLAMA_URL, json=payload, stream=False)
print("Total Time Taken: ", time.time()-start_time)
reply = response.json()["message"]["content"]
reply = re.sub(r"<think>.*?</think>", "", reply, flags=re.DOTALL).strip()

print(reply)
# Out:
# Total Time Taken:  44.110663175582886
# This line of Python code is using a generator expression with the `yield from` statement, which is a way to create and work with coroutines in Python. Let's break it down:
#
# 1. `{book.get("author") for book in books if book.get("author")}`: This is a generator expression that generates a sequence of author names from the `books` dictionary, where each book has an "author" key. It iterates over the `books` dictionary and yields the author's name for each book, as long as the book has an "author" key (the condition `if book.get("author")` ensures that only books with an "author" are considered).
#
# 2. The curly braces `{}` around the generator expression indicate that it is a dictionary comprehension, but since we're yielding values instead of creating a dictionary, it becomes a generator expression.
#
# 3. `yield from`: This keyword is used to delegate control to another coroutine or a generator. In this case, it is delegating the control to the generator created by the generator expression. When the main function calls this line, it doesn't execute the code inside the generator expression immediately; instead, it returns a generator object that can be iterated later.
#
# 4. When you call `next()` on this generator object, it will start executing the code inside the generator expression and yield the first author's name. Each subsequent call to `next()` will advance the iteration and yield the next author's name until there are no more authors left in the `books` dictionary.
#
# In summary, this line of code creates a generator that yields the names of authors from the `books` dictionary when called iteratively using functions like `next()`. It only considers books with an "author" key. The use of `yield from` makes it easier to work with coroutines and generators in a more concise manner compared to traditional generator functions.
