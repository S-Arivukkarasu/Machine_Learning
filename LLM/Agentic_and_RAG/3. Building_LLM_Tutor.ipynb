# %% [markdown]
# # Building LLM Tutor Assignment

# %%
# Importing the Libraries

import requests
import json
import time
import re
from typing import List
from bs4 import BeautifulSoup
from IPython.display import Markdown, display, update_display

# %%
MODEL_NAME="mistral"  # Get this from you local ollama by using "ollama list"
OLLAMA_URL = "http://localhost:11434/api/chat"

# %%
question = """
Please explain what this code does and why:
yield from {book.get("author") for book in books if book.get("author")}
"""

# %%
system_prompt = "You are a helpful technical tutor who answers questions about python code, software engineering, data science and LLMs"
user_prompt = "Please give a detailed explanation to the following question: " + question

# %%
messages = [
    {"role": "system", "content": system_prompt},
    {"role": "user", "content": user_prompt}
]

# %%
payload = {
        "model": MODEL_NAME,
        "messages": messages,
        "stream": False  # Important: to get streaming responses
    }

# %%
start_time = time.time()
response = requests.post(OLLAMA_URL, json=payload, stream=False)
print("Total Time Taken: ", time.time()-start_time)
reply = response.json()["message"]["content"]
reply = re.sub(r"<think>.*?</think>", "", reply, flags=re.DOTALL).strip()

print(reply)
# Out:
# Total Time Taken:  84.52378845214844
# This line of Python code is using a generator expression with a nested comprehension, specifically utilizing the `yield from` statement within a `{...}` dictionary comprehension context. Let's break it down:
#
# 1. `books`: Assuming that this variable contains a list or dictionary of dictionaries, where each dictionary represents a book with keys like "title", "publisher", and "author".
#
# 2. `book.get("author")`: For each `book`, it retrieves the value associated with the key "author". If the key does not exist in the current `book`, it returns `None`. However, due to the filtering condition applied later on, only books with an author will be included in the resulting generator.
#
# 3. `if book.get("author")`: This condition checks whether the book has an "author". If the value is `None`, the condition will evaluate to `False` and the current book will be skipped over.
#
# 4. `{...}`: This is a dictionary comprehension, which builds a new dictionary object with keys and values based on the provided expression. However, in this case, since we are using a generator expression, the resulting object is not actually a dictionary but rather a generator that yields each value as it is produced during iteration.
#
# 5. `yield from`: The `yield from` statement allows one generator to delegate its work to another. In this context, the generated iterator returns all values obtained by iterating over the results of the nested comprehension.
#
# 6. So, in summary, this code snippet creates a new generator that yields the author names for books in the `books` list or dictionary (assuming there are no missing authors), filtering out any books without an author. This is useful when you want to iterate over the generated sequence of authors but don't need to store all of them at once, as generators can save memory by producing items on-the-fly rather than storing them in a list or array.
